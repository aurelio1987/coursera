# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Marco Aurelio Frassi Orides**
#
# &nbsp;
# Data Scientist

# %% [markdown]
# *I wanto to become a data scientist because data might upgrade this world to a better and faster one*

# %% [markdown]
#  ### In the code below I'm programming a print of a famous sentence!

# %%
x = ('Hello, world!')

print (x)
# Out:
# Hello, world!

# %% [markdown]
# <ol>
#     <li>Blue</li>
#     <li>Brown</li>
#     <li>Red</li>
# </ol>
#
#
# [www.globo.com](#division_ID)
#
#
# |Name|Age|
# |----|----|
# |Gabriel|14|
# |
